# %% [markdown]
# # Tips

# %% [markdown]
# ### Introduction:
#
# This exercise was created based on the tutorial and documentation from [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html)
# The dataset being used is tips from Seaborn.
#
# ### Step 1. Import the necessary libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv("tips.csv")

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
tips.drop(columns = tips.loc[:, tips.columns.str.contains('^Unnamed')], inplace = True)
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
plt.hist(tips.total_bill);

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
colors = np.random.rand(tips.index.stop)
plt.scatter(x = tips.total_bill, y = tips.tip, c = colors);

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
sns.pairplot(tips[['total_bill','tip','size']]);

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
sns.pairplot(tips[['total_bill','day']]);

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
plt.scatter(y = tips.day, x = tips.tip, c = np.where(tips['sex'] == 'Male','r','y'));

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
# tips.boxplot(tips.total_bill)
# tips.groupby(['day','time'])['total_bill'].sum().reset_index()

# %%
tips[tips.time == 'Dinner']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.hist(tips[tips.time == 'Dinner'].tip);
ax2.hist(tips[tips.time == 'Lunch'].tip);

# %%
tips.index.stop
# Out:
# 244

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
yes_tips = tips[tips.smoker == 'Yes']
no_tips = tips[tips.smoker == 'No']
size, (ax1,ax2) = plt.subplots(2, figsize = (10,7))
ax1.scatter(x = yes_tips.total_bill  , y = yes_tips.tip, c = np.where(yes_tips.sex == 'Male','r','y'));
ax1.title.set_text('smoker')
ax2.scatter(x = no_tips.total_bill, y = no_tips.tip, c = np.where(no_tips.sex == 'Male','r','y'));
ax2.title.set_text('not smoker')

# %% [markdown]
# ### BONUS: Create your own question and answer it using a graph.
