# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Titanic_Desaster/train.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
titanic = pd.read_csv('train.csv')

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic.reindex(titanic.PassengerId).drop(columns = 'PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                 1.0     1.0
# 2                 1.0     3.0
# 3                 1.0     1.0
# 4                 0.0     3.0
# 5                 0.0     3.0
# ...               ...     ...
# 887               1.0     1.0
# 888               0.0     3.0
# 889               1.0     1.0
# 890               0.0     3.0
# 891               NaN     NaN
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                                       Heikkinen, Miss. Laina  female  26.0
# 3                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                                     Allen, Mr. William Henry    male  35.0
# 5                                             Moran, Mr. James    male   NaN
# ...                                                        ...     ...   ...
# 887                               Graham, Miss. Margaret Edith  female  19.0
# 888                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                                      Behr, Mr. Karl Howell    male  26.0
# 890                                        Dooley, Mr. Patrick    male  32.0
# 891                                                        NaN     NaN   NaN
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1              1.0    0.0          PC 17599  71.2833   C85        C
# 2              0.0    0.0  STON/O2. 3101282   7.9250   NaN        S
# 3              1.0    0.0            113803  53.1000  C123        S
# 4              0.0    0.0            373450   8.0500   NaN        S
# 5              0.0    0.0            330877   8.4583   NaN        Q
# ...            ...    ...               ...      ...   ...      ...
# 887            0.0    0.0            112053  30.0000   B42        S
# 888            1.0    2.0        W./C. 6607  23.4500   NaN        S
# 889            0.0    0.0            111369  30.0000  C148        C
# 890            0.0    0.0            370376   7.7500   NaN        Q
# 891            NaN    NaN               NaN      NaN   NaN      NaN
#
# [891 rows x 11 columns]

# %% [markdown]
# ### Step 5. Create a pie chart presenting the male/female proportion

# %%
plt.pie(titanic.groupby('Sex').PassengerId.count(), labels = ["male","female"]);

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
plt.scatter(x = titanic.Age, y = titanic.Fare, c = np.where(titanic.Sex == 'male','r','y'));

# %% [markdown]
# ### Step 7. How many people survived?

# %%
titanic.Survived.sum()
# Out:
# 342

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
plt.hist(titanic.Fare);

# %% [markdown]
# ### BONUS: Create your own question and answer it.
